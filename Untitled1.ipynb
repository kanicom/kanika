# %% [markdown]
# <a href="https://colab.research.google.com/github/kanicom/kanika/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
#define the dataset
x=np.array([2,3,5,7,8,9,10,15])
y=np.array([10,20,30,40,50,60,70,80])

# %%
def Pearson_correlation(x,y):
  if len(x)==len(y):
    Sum_xy=sum((x-x.mean())*(y-y.mean()))
    Sum_x_squared = sum((x-x.mean())**2)
    Sum_y_squared = sum((y-y.mean())**2)
    corr=Sum_xy/np.sqrt(Sum_x_squared*Sum_y_squared)
    return corr

print(Pearson_correlation(x,y))
print(Pearson_correlation(x,x))
# Out:
# 0.9714106153623109
# 1.0

# %%
print(np.corrcoef(x,y))
#matrix form
# Out:
# [[1.         0.97141062]
#  [0.97141062 1.        ]]

# %%
import pandas as pd
from sklearn.datasets import load_diabetes
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf

# %%
#load the dataset with frame
df=load_diabetes(as_frame=True)
df=df.frame
df.head()
# Out:
#         age       sex       bmi        bp        s1  ...        s3        s4        s5        s6  target
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223  ... -0.043401 -0.002592  0.019907 -0.017646   151.0
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449  ...  0.074412 -0.039493 -0.068332 -0.092204    75.0
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599  ... -0.032356 -0.002592  0.002861 -0.025930   141.0
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  ... -0.036038  0.034309  0.022688 -0.009362   206.0
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  ...  0.008142 -0.002592 -0.031988 -0.046641   135.0
#
# [5 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  target  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %%
#FIND pearson correlation
corr=df.corr(method='pearson')
corr
# Out:
#              age       sex       bmi        bp  ...        s4        s5        s6    target
# age     1.000000  0.173737  0.185085  0.335428  ...  0.203841  0.270774  0.301731  0.187889
# sex     0.173737  1.000000  0.088161  0.241010  ...  0.332115  0.149916  0.208133  0.043062
# bmi     0.185085  0.088161  1.000000  0.395411  ...  0.413807  0.446157  0.388680  0.586450
# bp      0.335428  0.241010  0.395411  1.000000  ...  0.257650  0.393480  0.390430  0.441482
# s1      0.260061  0.035277  0.249777  0.242464  ...  0.542207  0.515503  0.325717  0.212022
# s2      0.219243  0.142637  0.261170  0.185548  ...  0.659817  0.318357  0.290600  0.174054
# s3     -0.075181 -0.379090 -0.366811 -0.178762  ... -0.738493 -0.398577 -0.273697 -0.394789
# s4      0.203841  0.332115  0.413807  0.257650  ...  1.000000  0.617859  0.417212  0.430453
# s5      0.270774  0.149916  0.446157  0.393480  ...  0.617859  1.000000  0.464669  0.565883
# ...

# %%
#corr btw age nd sex
c= np.corrcoef(df['age'],df['sex'])
print('correlations between age and sex\n',c)
# Out:
# correlations between age and sex
#  [[1.        0.1737371]
#  [0.1737371 1.       ]]

# %%
plt.figure(figsize=(10,8),dpi=100)
sns.heatmap(corr,annot=True,fmt=".4f",linewidth=5)
plt.show()

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tcs=yf.download('TCS.NS',
      start='2020-01-01',
      end='2025-02-25',
      progress=False)
tcs
# Out:
# Price             Close         High          Low         Open   Volume
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2020-01-01  1948.981445  1963.637293  1936.753019  1949.341015  1354908
# 2020-01-02  1940.035400  1960.086329  1932.437688  1960.086329  2380752
# 2020-01-03  1978.698242  1998.794169  1945.744751  1945.744751  4655761
# 2020-01-06  1978.519043  2001.447188  1967.234755  1982.610187  3023209
# 2020-01-07  1983.374023  1991.286304  1963.547883  1978.563522  2429317
# ...                 ...          ...          ...          ...      ...
# 2025-02-18  3873.199951  3924.399902  3864.500000  3898.399902  2149879
# 2025-02-19  3784.100098  3874.949951  3768.149902  3872.199951  4366672
# 2025-02-20  3779.399902  3788.000000  3751.300049  3761.500000  2888572
# 2025-02-21  3786.000000  3817.000000  3775.000000  3776.100098  1833931
# 2025-02-24  3675.600098  3763.199951  3670.000000  3743.149902  2508516
#
# [1278 rows x 5 columns]

# %%
tcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1278 entries, 2020-01-01 to 2025-02-24
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (Close, TCS.NS)   1278 non-null   float64
#  1   (High, TCS.NS)    1278 non-null   float64
#  2   (Low, TCS.NS)     1278 non-null   float64
#  3   (Open, TCS.NS)    1278 non-null   float64
#  4   (Volume, TCS.NS)  1278 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 59.9 KB

# %%
tcs.Close
# Out:
# Ticker           TCS.NS
# Date
# 2020-01-01  1948.981445
# 2020-01-02  1940.035400
# 2020-01-03  1978.698242
# 2020-01-06  1978.519043
# 2020-01-07  1983.374023
# ...                 ...
# 2025-02-18  3873.199951
# 2025-02-19  3784.100098
# 2025-02-20  3779.399902
# 2025-02-21  3786.000000
# 2025-02-24  3675.600098
#
# [1278 rows x 1 columns]

# %%
c=tcs[['Close','Volume']]
c
# Out:
# Price             Close   Volume
# Ticker           TCS.NS   TCS.NS
# Date
# 2020-01-01  1948.981445  1354908
# 2020-01-02  1940.035400  2380752
# 2020-01-03  1978.698242  4655761
# 2020-01-06  1978.519043  3023209
# 2020-01-07  1983.374023  2429317
# ...                 ...      ...
# 2025-02-18  3873.199951  2149879
# 2025-02-19  3784.100098  4366672
# 2025-02-20  3779.399902  2888572
# 2025-02-21  3786.000000  1833931
# 2025-02-24  3675.600098  2508516
#
# [1278 rows x 2 columns]

# %%
import numpy as np
#define the dataset
x=np.array(['Volume'])
y=np.array(['Close'])

# %%
#FIND pearson correlation
corr=c.corr(method='pearson')
corr
# Out:
# Price           Close  Volume
# Ticker         TCS.NS  TCS.NS
# Price  Ticker
# Close  TCS.NS  1.0000 -0.3248
# Volume TCS.NS -0.3248  1.0000

# %%
c.corr()
# Out:
# Price           Close  Volume
# Ticker         TCS.NS  TCS.NS
# Price  Ticker
# Close  TCS.NS  1.0000 -0.3248
# Volume TCS.NS -0.3248  1.0000
